# %% [markdown]
# <a href="https://colab.research.google.com/github/ogundipeflorence53-collab/peace/blob/main/Copy_of_Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age = input("How old are you?")
print("my name is peace, im light in complexion from Ibadan, i am ", age, "years old, and i am the first born")
# Out:
# How old are you?12
# my name is peace, im light in complexion from Ibadan, i am  12 years old, and i am the first born

# %%
name = input("what is your name?")
print("i am self discipline, im light in complexion from Ibadan, i am ", age, "years old, and i am the first born"

# %%
# About Myself Program

#
name = "peace"
age = 12
hobby = "coding and wiring"
dream = "to become a software engineer"


#

#
print("Hello, my name is", name)
print("I am", age, "years old.")
print("My hobby is", hobby + ".")
print("My dream is", dream + ".")
# Out:
# Hello, my name is peace
# I am 12 years old.
# My hobby is coding and wiring.
# My dream is to become a software engineer.

# %%
about_me = {
    "Name": "Ada",
    "Age": 22,
    "Hobbies": ["Painting", "Coding", "Reading"],
    "Dream": "To build AI that helps people"
}

for key, value in about_me.items():
    print(f"{key}: {value}")
# Out:
# Name: Ada
# Age: 22
# Hobbies: ['Painting', 'Coding', 'Reading']
# Dream: To build AI that helps people
